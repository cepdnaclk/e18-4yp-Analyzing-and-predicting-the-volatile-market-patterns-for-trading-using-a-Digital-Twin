# %% [markdown]
# # Deep Reinforcement Learning for Deriv Trading volatility 100 (1s) Index

# %% [markdown]
# ![](Deriv_trading_platform_volatility100(1s)Index.png)

# %% [markdown]
# ## Content

# %% [markdown]
# 1.Task Description
#
#
# 2.Install Python packages
#
#     2.1. Install Packages
#     2.2. A List of Python Packages
#     2.3. Import Packages
#     2.4. Create Folders
#
#
# 3.Download and Preprocess Data
#
#
# 4.Preprocess Data
#
#     4.1. Technical Indicators
#     4.2. Perform Feature Engineering
#
#
# 5.Build Market Environment in OpenAI Gym-style
#
#     5.1. Data Split
#     5.3. Environment for Training
#
#
# 6.Train DRL Agents
#
#
# 7.Backtesting Performance
#
#     7.1. BackTestStats
#     7.2. BackTestPlot

# %% [markdown]
# ## Part 1. Task Description

# %% [markdown]
# We train a DRL agent for Deriv Trading volatility 100 (1s) Index. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
#         Balance
#         value
#         Techical indicators
#         date month time
#         1st 2nd 3rd derivatives.
#
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state.
#
#         Bid rise -> x dollars within y ticks
#         Bid fall -> x dollars within y ticks
#         Hold
#
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking ACTION a at STATE State s and arriving at NEW STATE s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#         profit = (ALPHA - 1) * x          where ALPHA = f(x,y)
#         loss   = -x
#
#
# * **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#         value in the market
#         date and time
#
#
# The data for this case study is obtained from Deriv Finance API. The data contains price and time for each second

# %% [markdown]
# ## Part 2. Install Python Packages

# %% [markdown]
# ### 2.1. Install packages

# %%
## install required packages
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt
## install finrl library
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: swig in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (4.1.1.post1)
# Requirement already satisfied: wrds in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (3.1.6)
# Requirement already satisfied: numpy in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from wrds) (1.26.3)
# Requirement already satisfied: pandas in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from wrds) (2.1.4)
# Requirement already satisfied: psycopg2-binary in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from wrds) (2.9.9)
# Requirement already satisfied: sqlalchemy<2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from wrds) (1.4.51)
# Requirement already satisfied: scipy in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from wrds) (1.11.4)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from sqlalchemy<2->wrds) (3.0.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pandas->wrds) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pandas->wrds) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->wrds) (1.16.0)
# Requirement already satisfied: pyportfolioopt in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (1.5.5)
# Requirement already satisfied: scipy<2.0,>=1.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyportfolioopt) (1.11.4)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyportfolioopt) (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyportfolioopt) (2.1.4)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyportfolioopt) (1.26.3)
# Requirement already satisfied: ecos>=2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (2.0.12)
# Requirement already satisfied: scs>=3.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (3.2.4.post1)
# Requirement already satisfied: osqp>=0.6.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (0.6.3)
# Requirement already satisfied: pybind11 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (2.11.1)
# Requirement already satisfied: clarabel>=0.5.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (0.6.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pandas>=0.19->pyportfolioopt) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pandas>=0.19->pyportfolioopt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pandas>=0.19->pyportfolioopt) (2023.3.post1)
# Requirement already satisfied: qdldl in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (0.1.7.post0)
# Requirement already satisfied: six>=1.5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyportfolioopt) (1.16.0)
# E: Could not open lock file /var/lib/apt/lists/lock - open (13: Permission denied)
# E: Unable to lock directory /var/lib/apt/lists/
# W: Problem unlinking the file /var/cache/apt/pkgcache.bin - RemoveCaches (13: Permission denied)
# W: Problem unlinking the file /var/cache/apt/srcpkgcache.bin - RemoveCaches (13: Permission denied)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-keknt26m
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-keknt26m
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 34a5a4be96109af4bb9e7a34877e975cd10c0b50
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-u79gxunc/elegantrl_461db1e5bac943fc95a7e8856a0f9c5f
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-u79gxunc/elegantrl_461db1e5bac943fc95a7e8856a0f9c5f
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit b4b9d662b9f9cb7cc368ac2b1036b5119eb20be4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyportfolioopt<2,>=1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (1.5.5)
# Requirement already satisfied: stable-baselines3[extra]>=2.0.0a5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (2.3.0a1)
# Requirement already satisfied: wrds<4,>=3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (3.1.6)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (3.2.0)
# Requirement already satisfied: exchange-calendars<5,>=4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (4.5.1)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (0.9.2)
# Requirement already satisfied: ray[default,tune]<3,>=2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (2.9.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (0.5.4)
# Requirement already satisfied: scikit-learn<2,>=1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (1.3.2)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (0.2.35)
# Requirement already satisfied: ccxt<4,>=3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (3.1.60)
# Requirement already satisfied: jqdatasdk<2,>=1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from finrl==0.3.6) (1.9.2)
# Requirement already satisfied: pandas>=0.18.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.4)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.7.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.9.1)
# Requirement already satisfied: websockets<11,>=9.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.3)
# Requirement already satisfied: requests<3,>2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.31.0)
# Requirement already satisfied: PyYAML==6.0.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.1)
# Requirement already satisfied: urllib3<2,>1.24 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.18)
# Requirement already satisfied: deprecation==2.1.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: msgpack==1.0.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: packaging in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.2)
# Requirement already satisfied: cryptography>=2.6.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (41.0.7)
# Requirement already satisfied: certifi>=2018.1.18 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (2023.11.17)
# Requirement already satisfied: aiodns>=1.1.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: setuptools>=60.9.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (69.0.3)
# Requirement already satisfied: yarl>=1.7.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (1.9.4)
# Requirement already satisfied: tzdata in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2023.4)
# Requirement already satisfied: korean-lunar-calendar in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.3.1)
# Requirement already satisfied: pyluach in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: toolz in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.0)
# Requirement already satisfied: python-dateutil in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: thriftpy2>=0.3.9 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (0.4.17)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.4.51)
# Requirement already satisfied: six in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: pymysql>=0.7.6 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.1.0)
# Requirement already satisfied: ipython>=3.2.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (8.20.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.8.2)
# Requirement already satisfied: pytz>=2014.10 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (2023.3.post1)
# Requirement already satisfied: scipy>=0.14.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.11.4)
# Requirement already satisfied: seaborn>=0.7.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.13.1)
# Requirement already satisfied: empyrical>=0.5.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.4.1)
# Requirement already satisfied: frozenlist in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.4.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.23.4)
# Requirement already satisfied: jsonschema in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.20.0)
# Requirement already satisfied: click>=7.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.7)
# Requirement already satisfied: aiosignal in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: filelock in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.13.1)
# Requirement already satisfied: pyarrow>=6.0.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (14.0.2)
# Requirement already satisfied: tensorboardX>=1.9 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6.2.2)
# Requirement already satisfied: fsspec in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2023.12.2)
# Requirement already satisfied: gpustat>=1.0.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.1.1)
# Requirement already satisfied: grpcio>=1.42.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.60.0)
# Requirement already satisfied: colorful in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.5.6)
# Requirement already satisfied: aiohttp-cors in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: smart-open in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (6.4.0)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (20.21.0)
# Requirement already satisfied: opencensus in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.11.4)
# Requirement already satisfied: py-spy>=0.2.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.14)
# Requirement already satisfied: prometheus-client>=0.7.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.19.0)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.5.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.2.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.29.1)
# Requirement already satisfied: cloudpickle in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: torch>=1.13 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.2)
# Requirement already satisfied: pillow in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (10.2.0)
# Requirement already satisfied: opencv-python in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9.0.80)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.15.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: shimmy[atari]~=1.3.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: tqdm in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.66.1)
# Requirement already satisfied: psutil in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.7)
# Requirement already satisfied: pygame in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: rich in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.7.0)
# Requirement already satisfied: psycopg2-binary in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.12.2)
# Requirement already satisfied: appdirs>=1.4.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: html5lib>=1.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.4.0)
# Requirement already satisfied: lxml>=4.9.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (5.1.0)
# Requirement already satisfied: peewee>=3.16.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.17.0)
# Requirement already satisfied: multitasking>=0.0.7 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: gym in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.26.2)
# Requirement already satisfied: pycares>=4.0.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6) (4.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.3)
# Requirement already satisfied: AutoROM.accept-rom-license in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.5)
# Requirement already satisfied: cffi>=1.12 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: osqp>=0.6.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.3)
# Requirement already satisfied: clarabel>=0.5.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.0)
# Requirement already satisfied: pybind11 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.11.1)
# Requirement already satisfied: scs>=3.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.4.post1)
# Requirement already satisfied: ecos>=2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.12)
# Requirement already satisfied: pandas-datareader>=0.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: blessed>=1.17.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (1.20.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (12.535.133)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9.0)
# Requirement already satisfied: webencodings in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Requirement already satisfied: exceptiongroup in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.43)
# Requirement already satisfied: traitlets>=5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.14.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.17.2)
# Requirement already satisfied: jedi>=0.16 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.19.1)
# Requirement already satisfied: pexpect>4.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.9.0)
# Requirement already satisfied: matplotlib-inline in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: decorator in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.1.1)
# Requirement already satisfied: stack-data in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.6.3)
# Requirement already satisfied: cycler>=0.10 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.47.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (2.14.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (0.6.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.3.2)
# Requirement already satisfied: ale-py~=0.8.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.8.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (3.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.26.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.5.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: absl-py>=0.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.0)
# Requirement already satisfied: ply<4.0,>=3.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.1.105)
# Requirement already satisfied: networkx in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.1.105)
# Requirement already satisfied: jinja2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (11.0.2.54)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.18.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (8.9.2.26)
# Requirement already satisfied: sympy in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.12)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.3.101)
# Requirement already satisfied: platformdirs<4,>=2.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (3.11.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.8)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.0.8)
# Requirement already satisfied: box2d-py==2.3.5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (2.3.5)
# Requirement already satisfied: swig==4.* in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (4.1.1.post1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.17.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.32.1)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.15.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: importlib-resources in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.1.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.2.13)
# Requirement already satisfied: pycparser in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.62.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.3)
# Requirement already satisfied: pure-eval in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from sympy->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ishta/Desktop/myenv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.2)

# %% [markdown]
# ### 2.2. A list of Python packages

# %% [markdown]
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# ### 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 9
#       6 import datetime
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 9 from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
#      10 from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
#      11 from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
#
# ModuleNotFoundError: No module named 'finrl'

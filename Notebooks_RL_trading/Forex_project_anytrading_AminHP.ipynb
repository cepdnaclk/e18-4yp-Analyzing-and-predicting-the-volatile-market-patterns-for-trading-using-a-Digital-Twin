# %% [markdown]
# # gym-anytrading
#
# `AnyTrading` is a collection of [OpenAI Gym](https://github.com/openai/gym) environments for reinforcement learning-based trading algorithms.
#
# Trading algorithms are mostly implemented in two markets: [FOREX](https://en.wikipedia.org/wiki/Foreign_exchange_market) and [Stock](https://en.wikipedia.org/wiki/Stock). AnyTrading aims to provide some Gym environments to improve and facilitate the procedure of developing and testing RL-based algorithms in this area. This purpose is obtained by implementing three Gym environments: **TradingEnv**, **ForexEnv**, and **StocksEnv**.
#
# TradingEnv is an abstract environment which is defined to support all kinds of trading environments. ForexEnv and StocksEnv are simply two environments that inherit and extend TradingEnv. In the future sections, more explanations will be given about them but before that, some environment properties should be discussed.
#
# **Note:** For experts, it is recommended to check out the [gym-mtsim](https://github.com/AminHP/gym-mtsim) project.
#
# ## Installation
#
# ### Via PIP
# ```bash
# pip install gym-anytrading
# ```
#
# ### From Repository
# ```bash
# git clone https://github.com/AminHP/gym-anytrading
# cd gym-anytrading
# pip install -e .
#
# ## or
#
# pip install --upgrade --no-deps --force-reinstall https://github.com/AminHP/gym-anytrading/archive/master.zip
# ```
#
# ## Environment Properties
# First of all, **you can't simply expect an RL agent to do everything for you and just sit back on your chair in such complex trading markets!**
# Things need to be simplified as much as possible in order to let the agent learn in a faster and more efficient way. In all trading algorithms, the first thing that should be done is to define **actions** and **positions**. In the two following subsections, I will explain these actions and positions and how to simplify them.
#
# ### Trading Actions
# If you search on the Internet for trading algorithms, you will find them using numerous actions such as **Buy**, **Sell**, **Hold**, **Enter**, **Exit**, etc.
# Referring to the first statement of this section, a typical RL agent can only solve a part of the main problem in this area. If you work in trading markets you will learn that deciding whether to hold, enter, or exit a pair (in FOREX) or stock (in Stocks) is a statistical decision depending on many parameters such as your budget, pairs or stocks you trade, your money distribution policy in multiple markets, etc. It's a massive burden for an RL agent to consider all these parameters and may take years to develop such an agent! In this case, you certainly will not use this environment but you will extend your own.
#
# So after months of work, I finally found out that these actions just make things complicated with no real positive impact. In fact, they just increase the learning time and an action like **Hold** will be barely used by a well-trained agent because it doesn't want to miss a single penny. Therefore there is no need to have such numerous actions and only `Sell=0` and `Buy=1` actions are adequate to train an agent just as well.
#
# ### Trading Positions
# If you're not familiar with trading positions, refer [here](https://en.wikipedia.org/wiki/Position_\(finance\)). It's a very important concept and you should learn it as soon as possible.
#
# In a simple vision: **Long** position wants to buy shares when prices are low and profit by sticking with them while their value is going up, and **Short** position wants to sell shares with high value and use this value to buy shares at a lower value, keeping the difference as profit.
#
# Again, in some trading algorithms, you may find numerous positions such as **Short**, **Long**, **Flat**, etc. As discussed earlier, I use only `Short=0` and `Long=1` positions.
#
# ## Trading Environments
# As I noticed earlier, now it's time to introduce the three environments. Before creating this project, I spent so much time to search for a simple and flexible Gym environment for any trading market but didn't find one. They were almost a bunch of complex codes with many unclear parameters that you couldn't simply look at them and comprehend what's going on. So I concluded to implement this project with a great focus on simplicity, flexibility, and comprehensiveness.
#
# In the three following subsections, I will introduce our trading environments and in the next section, some IPython examples will be mentioned and briefly explained.
#
# ### TradingEnv
# TradingEnv is an abstract class which inherits `gym.Env`. This class aims to provide a general-purpose environment for all kinds of trading markets. Here I explain its public properties and methods. But feel free to take a look at the complete [source code](https://github.com/AminHP/gym-anytrading/blob/master/gym_anytrading/envs/trading_env.py).
#
# * Properties:
# > `df`: An abbreviation for **DataFrame**. It's a **pandas'** DataFrame which contains your dataset and is passed in the class' constructor.
# >
# > `prices`: Real prices over time. Used to calculate profit and render the environment.
# >
# > `signal_features`: Extracted features over time. Used to create *Gym observations*.
# >
# > `window_size`: Number of ticks (current and previous ticks) returned as a *Gym observation*. It is passed in the class' constructor.
# >
# > `action_space`: The *Gym action_space* property. Containing discrete values of **0=Sell** and **1=Buy**.
# >
# > `observation_space`: The *Gym observation_space* property. Each observation is a window on `signal_features` from index **current_tick - window_size + 1** to **current_tick**. So `_start_tick` of the environment would be equal to `window_size`. In addition, initial value for `_last_trade_tick` is **window_size - 1** .
# >
# > `shape`: Shape of a single observation.
# >
# > `history`: Stores the information of all steps.
#
# * Methods:
# > `seed`: Typical *Gym seed* method.
# >
# > `reset`: Typical *Gym reset* method.
# >
# > `step`: Typical *Gym step* method.
# >
# > `render`: Typical *Gym render* method. Renders the information of the environment's current tick.
# >
# > `render_all`: Renders the whole environment.
# >
# > `close`: Typical *Gym close* method.
#
# * Abstract Methods:
# > `_process_data`: It is called in the constructor and returns `prices` and `signal_features` as a tuple. In different trading markets, different features need to be obtained. So this method enables our TradingEnv to be a general-purpose environment and specific features can be returned for specific environments such as *FOREX*, *Stocks*, etc.
# >
# > `_calculate_reward`: The reward function for the RL agent.
# >
# > `_update_profit`: Calculates and updates total profit which the RL agent has achieved so far. Profit indicates the amount of units of currency you have achieved by starting with *1.0* unit (Profit = FinalMoney / StartingMoney).
# >
# > `max_possible_profit`: The maximum possible profit that an RL agent can obtain regardless of trade fees.
#
# ### ForexEnv
# This is a concrete class which inherits TradingEnv and implements its abstract methods. Also, it has some specific properties for the *FOREX* market. For more information refer to the [source code](https://github.com/AminHP/gym-anytrading/blob/master/gym_anytrading/envs/forex_env.py).
#
# * Properties:
# > `frame_bound`: A tuple which specifies the start and end of `df`. It is passed in the class' constructor.
# >
# > `unit_side`: Specifies the side you start your trading. Containing string values of **left** (default value) and **right**. As you know, there are two sides in a currency pair in *FOREX*. For example in the *EUR/USD* pair, when you choose the `left` side, your currency unit is *EUR* and you start your trading with 1 EUR. It is passed in the class' constructor.
# >
# > `trade_fee`: A default constant fee which is subtracted from the real prices on every trade.
#
#
# ### StocksEnv
# Same as ForexEnv but for the *Stock* market. For more information refer to the [source code](https://github.com/AminHP/gym-anytrading/blob/master/gym_anytrading/envs/stocks_env.py).
#
# * Properties:
# > `frame_bound`: A tuple which specifies the start and end of `df`. It is passed in the class' constructor.
# >
# > `trade_fee_bid_percent`: A default constant fee percentage for bids. For example with trade_fee_bid_percent=0.01, you will lose 1% of your money every time you sell your shares.
# >
# > `trade_fee_ask_percent`: A default constant fee percentage for asks. For example with trade_fee_ask_percent=0.005, you will lose 0.5% of your money every time you buy some shares.
#
# Besides, you can create your own customized environment by extending TradingEnv or even ForexEnv or StocksEnv with your desired policies for calculating reward, profit, fee, etc.

# %% [markdown]
# ## Create an environment after preprocessing

# %%
import gymnasium as gym
import gym_anytrading
import matplotlib.pyplot as plt

# %%
import os
import pandas as pd
import numpy as np
os.chdir('/home/ishta/Analyzing-and-predicting-the-volatile-market-patterns-for-trading/Notebooks_RL_trading')

# %%
data = pd.read_csv('Datasets/eurusd_hour.csv')

# %%
data
# Out:
#              Date   Time       BO       BH       BL       BC      BCh  \
# 0      2005-05-02  00:00  1.28520  1.28520  1.28400  1.28440 -0.00080
# 1      2005-05-02  01:00  1.28440  1.28480  1.28390  1.28420 -0.00020
# 2      2005-05-02  02:00  1.28430  1.28540  1.28410  1.28510  0.00080
# 3      2005-05-02  03:00  1.28510  1.28590  1.28500  1.28510  0.00000
# 4      2005-05-02  04:00  1.28520  1.28590  1.28490  1.28550  0.00030
# ...           ...    ...      ...      ...      ...      ...      ...
# 93079  2020-04-29  18:00  1.08620  1.08851  1.08611  1.08713  0.00093
# 93080  2020-04-29  19:00  1.08711  1.08823  1.08659  1.08748  0.00037
# 93081  2020-04-29  20:00  1.08747  1.08788  1.08691  1.08708 -0.00039
# 93082  2020-04-29  21:00  1.08708  1.08740  1.08699  1.08714  0.00006
# 93083  2020-04-29  22:00  1.08728  1.08760  1.08727  1.08743  0.00015
#
#             AO       AH       AL       AC      ACh
# 0      1.28540  1.28540  1.28420  1.28460 -0.00080
# 1      1.28460  1.28500  1.28410  1.28440 -0.00020
# 2      1.28450  1.28560  1.28430  1.28530  0.00080
# 3      1.28530  1.28610  1.28520  1.28530  0.00000
# 4      1.28540  1.28610  1.28510  1.28570  0.00030
# ...        ...      ...      ...      ...      ...
# 93079  1.08660  1.08865  1.08640  1.08726  0.00066
# 93080  1.08725  1.08837  1.08675  1.08760  0.00035
# 93081  1.08758  1.08810  1.08706  1.08808  0.00050
# 93082  1.08808  1.08814  1.08763  1.08766 -0.00042
# 93083  1.08756  1.08779  1.08749  1.08760  0.00004
#
# [93084 rows x 12 columns]

# %%
data.rename(columns={'BC': 'Close'}, inplace=True)

# %%
data
# Out:
#              Date   Time       BO       BH       BL    Close      BCh  \
# 0      2005-05-02  00:00  1.28520  1.28520  1.28400  1.28440 -0.00080
# 1      2005-05-02  01:00  1.28440  1.28480  1.28390  1.28420 -0.00020
# 2      2005-05-02  02:00  1.28430  1.28540  1.28410  1.28510  0.00080
# 3      2005-05-02  03:00  1.28510  1.28590  1.28500  1.28510  0.00000
# 4      2005-05-02  04:00  1.28520  1.28590  1.28490  1.28550  0.00030
# ...           ...    ...      ...      ...      ...      ...      ...
# 93079  2020-04-29  18:00  1.08620  1.08851  1.08611  1.08713  0.00093
# 93080  2020-04-29  19:00  1.08711  1.08823  1.08659  1.08748  0.00037
# 93081  2020-04-29  20:00  1.08747  1.08788  1.08691  1.08708 -0.00039
# 93082  2020-04-29  21:00  1.08708  1.08740  1.08699  1.08714  0.00006
# 93083  2020-04-29  22:00  1.08728  1.08760  1.08727  1.08743  0.00015
#
#             AO       AH       AL       AC      ACh
# 0      1.28540  1.28540  1.28420  1.28460 -0.00080
# 1      1.28460  1.28500  1.28410  1.28440 -0.00020
# 2      1.28450  1.28560  1.28430  1.28530  0.00080
# 3      1.28530  1.28610  1.28520  1.28530  0.00000
# 4      1.28540  1.28610  1.28510  1.28570  0.00030
# ...        ...      ...      ...      ...      ...
# 93079  1.08660  1.08865  1.08640  1.08726  0.00066
# 93080  1.08725  1.08837  1.08675  1.08760  0.00035
# 93081  1.08758  1.08810  1.08706  1.08808  0.00050
# 93082  1.08808  1.08814  1.08763  1.08766 -0.00042
# 93083  1.08756  1.08779  1.08749  1.08760  0.00004
#
# [93084 rows x 12 columns]

# %%
env_name = 'forex-v0'

# %%
gym.envs.registry.keys()
# Out:
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v2', 'LunarLanderContinuous-v2', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v2', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v0', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Pusher-v2', 'Pusher-v4', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'GymV21Environment-v0', 'GymV26Environment-v0', 'forex-v0', 'stocks-v0'])

# %% [markdown]
# ### TradingEnv
#
# TradingEnv is an **abstract class** which inherits `gym.Env`. This class aims to provide a general-purpose environment for all kinds of trading markets. Here I explain its public properties and methods. But feel free to take a look at the complete [source code](https://github.com/AminHP/gym-anytrading/blob/master/gym_anytrading/envs/trading_env.py).
#
# - Properties:
#
# > df: An abbreviation for DataFrame. It's a pandas' DataFrame which contains your dataset and is passed in the class' constructor.
# >
# >
# > `prices`: Real prices over time. Used to calculate profit and render the environment.
# >
# > `signal_features`: Extracted features over time. Used to create *Gym observations*.
# >
# > `window_size`: Number of ticks (current and previous ticks) returned as a *Gym observation*. It is passed in the class' constructor.
# >
# > `action_space`: The *Gym action_space* property. Containing discrete values of **0=Sell** and **1=Buy**.
# >
# > `observation_space`: The *Gym observation_space* property. Each observation is a window on `signal_features` from index **current_tick - window_size + 1** to **current_tick**. So `_start_tick` of the environment would be equal to `window_size`. In addition, initial value for `_last_trade_tick` is **window_size - 1** .
# >
# > `shape`: Shape of a single observation.
# >
# > `history`: Stores the information of all steps.
# >
# - Methods:
#
# > seed: Typical Gym seed method.
# >
# >
# > `reset`: Typical *Gym reset* method.
# >
# > `step`: Typical *Gym step* method.
# >
# > `render`: Typical *Gym render* method. Renders the information of the environment's current tick.
# >
# > `render_all`: Renders the whole environment.
# >
# > `close`: Typical *Gym close* method.
# >
# - Abstract Methods:
#
# > _process_data: It is called in the constructor and returns prices and signal_features as a tuple. In different trading markets, different features need to be obtained. So this method enables our TradingEnv to be a general-purpose environment and specific features can be returned for specific environments such as FOREX, Stocks, etc.
# >
# >
# > `_calculate_reward`: The reward function for the RL agent.
# >
# > `_update_profit`: Calculates and updates total profit which the RL agent has achieved so far. Profit indicates the amount of units of currency you have achieved by starting with *1.0* unit (Profit = FinalMoney / StartingMoney).
# >
# > `max_possible_profit`: The maximum possible profit that an RL agent can obtain regardless of trade fees.
# >

# %% [markdown]
# ### ForexEnv
#
# This is a **concrete class** which inherits TradingEnv and implements its abstract methods. Also, it has some specific properties for the *FOREX* market. For more information refer to the [source code](https://github.com/AminHP/gym-anytrading/blob/master/gym_anytrading/envs/forex_env.py).
#
# - Properties:
#
# > frame_bound: A tuple which specifies the start and end of df. It is passed in the class' constructor.
# >
# >
# > `unit_side`: Specifies the side you start your trading. Containing string values of **left** (default value) and **right**. As you know, there are two sides in a currency pair in *FOREX*. For example in the *EUR/USD* pair, when you choose the `left` side, your currency unit is *EUR* and you start your trading with 1 EUR. It is passed in the class' constructor.
# >
# > `trade_fee`: A default constant fee which is subtracted from the real prices on every trade.
# >

# %% [markdown]
# #### window_size: Number of ticks (current and previous ticks) returned as a Gym observation. It is passed in the class' constructor.

# %%
forex_env = gym.make(
    env_name,
    df=data,
    window_size=100,
    frame_bound=(100, 1000),
    unit_side='left'
)

# %%
forex_env.signal_features
# Out:
# /home/ishta/anaconda3/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.signal_features to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.signal_features` for environment variables or `env.get_wrapper_attr('signal_features')` that will search the reminding wrappers.
#   logger.warn(
# array([[ 1.28440e+00,  0.00000e+00],
#        [ 1.28420e+00, -2.00000e-04],
#        [ 1.28510e+00,  9.00000e-04],
#        ...,
#        [ 1.20813e+00, -1.07000e-03],
#        [ 1.20781e+00, -3.20000e-04],
#        [ 1.20761e+00, -2.00000e-04]], dtype=float32)

# %% [markdown]
# - It is to be noted that the first element of `frame_bound` should be greater than or equal to `window_size`.

# %% [markdown]
# ### Print some information

# %%
print()
print("forex_env information:")
print("> shape:", forex_env.unwrapped.shape)
print("> df.shape:", forex_env.unwrapped.df.shape)
print("> prices.shape:", forex_env.unwrapped.prices.shape)
print("> signal_features.shape:", forex_env.unwrapped.signal_features.shape)
print("> max_possible_profit:", forex_env.unwrapped.max_possible_profit())
# Out:
# forex_env information:
# > shape: (100, 2)
# > df.shape: (93084, 12)
# > prices.shape: (1000,)
# > signal_features.shape: (1000, 2)
# > max_possible_profit: 1.3659421200501596

# %% [markdown]
# #### reset  Method:
# - Resets the environment to the initial state.
# - Seeds the random number generator for reproducibility.
# - Initializes various internal variables.

# %%
state, info=forex_env.reset()

# %%
state
# Out:
# array([[ 1.28420e+00, -2.00000e-04],
#        [ 1.28510e+00,  9.00000e-04],
#        [ 1.28510e+00,  0.00000e+00],
#        [ 1.28550e+00,  4.00000e-04],
#        [ 1.28540e+00, -1.00000e-04],
#        [ 1.28585e+00,  4.50000e-04],
#        [ 1.28555e+00, -3.00000e-04],
#        [ 1.28640e+00,  8.50000e-04],
#        [ 1.28680e+00,  4.00000e-04],
#        [ 1.28715e+00,  3.50000e-04],
#        [ 1.28600e+00, -1.15000e-03],
#        [ 1.28590e+00, -1.00000e-04],
#        [ 1.28620e+00,  3.00000e-04],
#        [ 1.28367e+00, -2.53000e-03],
#        [ 1.28567e+00,  2.00000e-03],
#        [ 1.28442e+00, -1.25000e-03],
#        [ 1.28502e+00,  6.00000e-04],
#        [ 1.28600e+00,  9.80000e-04],
#        [ 1.28580e+00, -2.00000e-04],
#        [ 1.28630e+00,  5.00000e-04],
#        [ 1.28510e+00, -1.20000e-03],
#        [ 1.28450e+00, -6.00000e-04],
#        [ 1.28540e+00,  9.00000e-04],
#        [ 1.28520e+00, -2.00000e-04],
#        [ 1.28330e+00, -1.90000e-03],
#        [ 1.28330e+00,  0.00000e+00],
#        [ 1.28350e+00,  2.00000e-04],
#        [ 1.28320e+00, -3.00000e-04],
#        [ 1.28355e+00,  3.50000e-04],
#        [ 1.28490e+00,  1.35000e-03],
#        [ 1.28595e+00,  1.05000e-03],
#        [ 1.28620e+00,  2.50000e-04],
#        [ 1.28690e+00,  7.00000e-04],
#        [ 1.28580e+00, -1.10000e-03],
#        [ 1.28590e+00,  1.00000e-04],
#        [ 1.28600e+00,  1.00000e-04],
#        [ 1.28950e+00,  3.50000e-03],
#        [ 1.28859e+00, -9.10000e-04],
#        [ 1.28880e+00,  2.10000e-04],
#        [ 1.28890e+00,  1.00000e-04],
#        [ 1.28880e+00, -1.00000e-04],
#        [ 1.28650e+00, -2.30000e-03],
#        [ 1.28883e+00,  2.33000e-03],
#        [ 1.28713e+00, -1.70000e-03],
#        [ 1.28723e+00,  1.00000e-04],
#        [ 1.28843e+00,  1.20000e-03],
#        [ 1.28783e+00, -6.00000e-04],
#        [ 1.28863e+00,  8.00000e-04],
#        [ 1.29623e+00,  7.60000e-03],
#        [ 1.29613e+00, -1.00000e-04],
#        [ 1.29573e+00, -4.00000e-04],
#        [ 1.29613e+00,  4.00000e-04],
#        [ 1.29563e+00, -5.00000e-04],
#        [ 1.29475e+00, -8.80000e-04],
#        [ 1.29375e+00, -1.00000e-03],
#        [ 1.29455e+00,  8.00000e-04],
#        [ 1.29465e+00,  1.00000e-04],
#        [ 1.29555e+00,  9.00000e-04],
#        [ 1.29510e+00, -4.50000e-04],
#        [ 1.29510e+00,  0.00000e+00],
#        [ 1.29570e+00,  6.00000e-04],
#        [ 1.29543e+00, -2.70000e-04],
#        [ 1.29353e+00, -1.90000e-03],
#        [ 1.29353e+00,  0.00000e+00],
#        [ 1.29403e+00,  5.00000e-04],
#        [ 1.29413e+00,  1.00000e-04],
#        [ 1.29433e+00,  2.00000e-04],
#        [ 1.29453e+00,  2.00000e-04],
#        [ 1.29530e+00,  7.70000e-04],
#        [ 1.29480e+00, -5.00000e-04],
#        [ 1.29430e+00, -5.00000e-04],
#        [ 1.29370e+00, -6.00000e-04],
#        [ 1.29340e+00, -3.00000e-04],
#        [ 1.29330e+00, -1.00000e-04],
#        [ 1.29380e+00,  5.00000e-04],
#        [ 1.29520e+00,  1.40000e-03],
#        [ 1.29550e+00,  3.00000e-04],
#        [ 1.29595e+00,  4.50000e-04],
#        [ 1.29745e+00,  1.50000e-03],
#        [ 1.29785e+00,  4.00000e-04],
#        [ 1.29655e+00, -1.30000e-03],
#        [ 1.29580e+00, -7.50000e-04],
#        [ 1.29537e+00, -4.30000e-04],
#        [ 1.29650e+00,  1.13000e-03],
#        [ 1.29485e+00, -1.65000e-03],
#        [ 1.29413e+00, -7.20000e-04],
#        [ 1.29363e+00, -5.00000e-04],
#        [ 1.29523e+00,  1.60000e-03],
#        [ 1.29413e+00, -1.10000e-03],
#        [ 1.29463e+00,  5.00000e-04],
#        [ 1.29563e+00,  1.00000e-03],
#        [ 1.29563e+00,  0.00000e+00],
#        [ 1.29540e+00, -2.30000e-04],
#        [ 1.29520e+00, -2.00000e-04],
#        [ 1.29450e+00, -7.00000e-04],
#        [ 1.29440e+00, -1.00000e-04],
#        [ 1.29390e+00, -5.00000e-04],
#        [ 1.29440e+00,  5.00000e-04],
#        [ 1.29420e+00, -2.00000e-04],
#        [ 1.29390e+00, -3.00000e-04]], dtype=float32)

# %%
info
# Out:
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': <Positions.Short: 0>}

# %%
forex_env.render()

# %%
forex_env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# - **Short** and **Long** positions are shown in `red` and `green` colors.
# - As you see, the starting *position* of the environment is always **Short**.

# %% [markdown]
# ### Trading Positions
# If you're not familiar with trading positions, refer here. It's a very important concept and you should learn it as soon as possible.
#
# In a simple vision: Long position wants to buy shares when prices are low and profit by sticking with them while their value is going up, and Short position wants to sell shares with high value and use this value to buy shares at a lower value, keeping the difference as profit.
#
# Again, in some trading algorithms, you may find numerous positions such as Short, Long, Flat, etc. As discussed earlier, I use only Short=0 and Long=1 positions.

# %%
while True:
    action = forex_env.action_space.sample()
    state, reward, terminated, truncated, info = forex_env.step(action)
    done = terminated or truncated

    if done:
        print("info:", info)
        break
# Out:
# info: {'total_reward': -148.31185340881348, 'total_profit': 0.9749644063677164, 'position': <Positions.Short: 0>}

# %%
plt.cla()
forex_env.unwrapped.render_all()
plt.show()

# %% [markdown]
# 1. **`while True:`**:
#     - This initiates an infinite loop, meaning the code inside will keep executing repeatedly until explicitly broken out of.
# 2. **`action = forex_env.action_space.sample()`**:
#     - This line selects a random action from the action space of the Forex environment. In reinforcement learning, an agent takes actions in an environment, and the action space defines the set of all possible actions the agent can take.
# 3. **`state, reward, terminated, truncated, info = forex_env.step(action)`**:
#     - The selected action is applied to the Forex environment using the **`step`** method, which returns several values:
#         - **`state`**: The new state or observation of the environment after taking the action.
#         - **`reward`**: The reward received by the agent for the action.
#         - **`terminated`**: A boolean indicating whether the episode (interaction with the environment) has terminated.
#         - **`truncated`**: A boolean indicating whether the episode was truncated (cut off) due to some limit.
#         - **`info`**: Additional information about the environment's state after the action.
# 4. **`done = terminated or truncated`**:
#     - The **`done`** variable is set to **`True`** if either the episode is terminated (**`terminated`** is **`True`**) or if it is truncated (**`truncated`** is **`True`**).
# 5. **`if done:`**:
#     - This checks whether the episode is done (either terminated or truncated).
# 6. **`print("info:", info)`**:
#     - If the episode is done, it prints the information (**`info`**) about the environment state.
# 7. **`break`**:
#     - This statement breaks out of the infinite loop, effectively ending the program.
#
# Overall, this code seems to be running a simple loop where the agent takes random actions in the Forex environment until the episode is done, and then it prints information about the environment state before terminating.

# %% [markdown]
# - You can use `render_all` method to avoid rendering on each step and prevent time-wasting.
# - As you see, the first **10** points (`window_size`=10) on the plot don't have a *position*. Because they aren't involved in calculating reward, profit, etc. They just display the first observations. So the environment's `_start_tick` and initial `_last_trade_tick` are **10** and **9**.

# %% [markdown]
# ### Create environment

# %%
# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO

# %%
forex_env = gym.make('forex-v0', df=data, frame_bound=(100,1000), window_size=100)
forex_env.observation_space
# Out:
# Box(-10000000000.0, 10000000000.0, (100, 2), float32)

# %% [markdown]
# ### Train Env

# %%
forex_env.reset(seed=2023)
model = PPO('MlpPolicy', forex_env, verbose=1)
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 899      |
# |    ep_rew_mean     | 65.5     |
# | time/              |          |
# |    fps             | 1411     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 4.78         |
# | time/                   |              |
# |    fps                  | 1172         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0009216389 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 3.52e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 838          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 1.89e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -79.8         |
# | time/                   |               |
# |    fps                  | 1083          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00053889357 |
# |    clip_fraction        | 0.0713        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.678        |
# |    explained_variance   | 0.000152      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.03e+03      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00424      |
# |    value_loss           | 1.66e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -23.5       |
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007732719 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | 4.6e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+03     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.000184    |
# |    value_loss           | 2.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 1045        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.000579884 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | -4.41e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 895         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.000116    |
# |    value_loss           | 1.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -7.21       |
# | time/                   |             |
# |    fps                  | 1042        |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011794925 |
# |    clip_fraction        | 0.00659     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 1.9e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00221    |
# |    value_loss           | 1.69e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 3.92         |
# | time/                   |              |
# |    fps                  | 1039         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0008596305 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -0.00012     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 871          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 0.0009       |
# |    value_loss           | 1.76e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 41.9         |
# | time/                   |              |
# |    fps                  | 1037         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0139368335 |
# |    clip_fraction        | 0.0808       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.645       |
# |    explained_variance   | 2.19e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 477          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00592     |
# |    value_loss           | 1.69e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 74.1        |
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011037714 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 4.2e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 629         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 1035         |
# |    iterations           | 10           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0029625483 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 1.13e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 667          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 4.46e-05     |
# |    value_loss           | 1.35e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 1035        |
# |    iterations           | 11          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006918577 |
# |    clip_fraction        | 0.0082      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 1.18e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000196   |
# |    value_loss           | 1.56e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 1035         |
# |    iterations           | 12           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0086093135 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 3.81e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 626          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00116      |
# |    value_loss           | 1.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 1035         |
# |    iterations           | 13           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0036294418 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 3.22e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 479          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00098     |
# |    value_loss           | 1.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 272          |
# | time/                   |              |
# |    fps                  | 1034         |
# |    iterations           | 14           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0065806545 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 7.75e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 771          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 1.62e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 263          |
# | time/                   |              |
# |    fps                  | 1032         |
# |    iterations           | 15           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0040428066 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 891          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000124    |
# |    value_loss           | 1.85e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 16           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0004619794 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 1.37e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 683          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000711    |
# |    value_loss           | 1.57e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 266         |
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 17          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005170728 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 732         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000192   |
# |    value_loss           | 1.39e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | 301        |
# | time/                   |            |
# |    fps                  | 1024       |
# |    iterations           | 18         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00363863 |
# |    clip_fraction        | 0.0157     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.395     |
# |    explained_variance   | 3.93e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 754        |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.000263   |
# |    value_loss           | 1.47e+03   |
# ----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 899            |
# |    ep_rew_mean          | 309            |
# | time/                   |                |
# |    fps                  | 1022           |
# |    iterations           | 19             |
# |    time_elapsed         | 38             |
# |    total_timesteps      | 38912          |
# | train/                  |                |
# |    approx_kl            | 0.000104663515 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.362         |
# |    explained_variance   | 3.34e-06       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 719            |
# |    n_updates            | 180            |
# |    policy_gradient_loss | 0.000308       |
# |    value_loss           | 1.62e+03       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 326           |
# | time/                   |               |
# |    fps                  | 1018          |
# |    iterations           | 20            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00051891897 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.385        |
# |    explained_variance   | 3.76e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 705           |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 0.000425      |
# |    value_loss           | 1.64e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 323          |
# | time/                   |              |
# |    fps                  | 1016         |
# |    iterations           | 21           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0002700103 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.411       |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 603          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -8.65e-05    |
# |    value_loss           | 1.35e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 352           |
# | time/                   |               |
# |    fps                  | 1015          |
# |    iterations           | 22            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00074578635 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.414        |
# |    explained_variance   | 2.38e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 931           |
# |    n_updates            | 210           |
# |    policy_gradient_loss | 0.000365      |
# |    value_loss           | 1.71e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 363           |
# | time/                   |               |
# |    fps                  | 1013          |
# |    iterations           | 23            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00027560367 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.388        |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 835           |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -6.53e-05     |
# |    value_loss           | 1.42e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 380           |
# | time/                   |               |
# |    fps                  | 1012          |
# |    iterations           | 24            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00018554402 |
# |    clip_fraction        | 0.0254        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.376        |
# |    explained_variance   | 1.61e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 946           |
# |    n_updates            | 230           |
# |    policy_gradient_loss | 0.000706      |
# |    value_loss           | 1.4e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 394          |
# | time/                   |              |
# |    fps                  | 1010         |
# |    iterations           | 25           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0012506037 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.389       |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 595          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 5.18e-05     |
# |    value_loss           | 1.61e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 417          |
# | time/                   |              |
# |    fps                  | 1009         |
# |    iterations           | 26           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0004576376 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.399       |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 765          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.000589     |
# |    value_loss           | 2.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 419          |
# | time/                   |              |
# |    fps                  | 1008         |
# |    iterations           | 27           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0033597713 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.35        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 851          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000803    |
# |    value_loss           | 1.57e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 431          |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 28           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 8.540627e-05 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.38        |
# |    explained_variance   | 9.54e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 622          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000359    |
# |    value_loss           | 1.7e+03      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 444           |
# | time/                   |               |
# |    fps                  | 1007          |
# |    iterations           | 29            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00035676488 |
# |    clip_fraction        | 0.0105        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.383        |
# |    explained_variance   | 1.23e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 579           |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.001        |
# |    value_loss           | 1.13e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 453          |
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 30           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0011897046 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.398       |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 891          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000481    |
# |    value_loss           | 1.74e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 477          |
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 31           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0020460575 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.416       |
# |    explained_variance   | 5.96e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 877          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000369    |
# |    value_loss           | 1.45e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 481         |
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 32          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003957876 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 842         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00155     |
# |    value_loss           | 1.58e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 492          |
# | time/                   |              |
# |    fps                  | 1008         |
# |    iterations           | 33           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0005059908 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.000693     |
# |    value_loss           | 1.8e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 488         |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 34          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.001230114 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.39       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 709         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 2.87e-05    |
# |    value_loss           | 1.43e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 492           |
# | time/                   |               |
# |    fps                  | 1006          |
# |    iterations           | 35            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00021965461 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.409        |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 768           |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 7.66e-05      |
# |    value_loss           | 1.48e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 494          |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 36           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0018097633 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.42        |
# |    explained_variance   | 1.85e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 725          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000525    |
# |    value_loss           | 1.61e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1005         |
# |    iterations           | 37           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0030597956 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.429       |
# |    explained_variance   | 0.000624     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 726          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 1.62e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 512           |
# | time/                   |               |
# |    fps                  | 1005          |
# |    iterations           | 38            |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00021653599 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.414        |
# |    explained_variance   | 0.00459       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 887           |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.00042      |
# |    value_loss           | 1.79e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 508           |
# | time/                   |               |
# |    fps                  | 1005          |
# |    iterations           | 39            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00058157346 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.405        |
# |    explained_variance   | 0.00144       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 555           |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 0.000238      |
# |    value_loss           | 1.29e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 506         |
# | time/                   |             |
# |    fps                  | 1005        |
# |    iterations           | 40          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.003341969 |
# |    clip_fraction        | 0.0061      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | 0.000424    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 870         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00064    |
# |    value_loss           | 1.97e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 506          |
# | time/                   |              |
# |    fps                  | 1005         |
# |    iterations           | 41           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 1.575891e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | 0.00352      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 676          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 5.09e-05     |
# |    value_loss           | 1.95e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 501          |
# | time/                   |              |
# |    fps                  | 1005         |
# |    iterations           | 42           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 4.599453e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.486       |
# |    explained_variance   | 0.0175       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1e+03        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000126    |
# |    value_loss           | 1.77e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 503           |
# | time/                   |               |
# |    fps                  | 1004          |
# |    iterations           | 43            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00015622581 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.489        |
# |    explained_variance   | 0.031         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 457           |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000207     |
# |    value_loss           | 1.48e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 506          |
# | time/                   |              |
# |    fps                  | 1004         |
# |    iterations           | 44           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0003289556 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.0382       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 732          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 4.16e-05     |
# |    value_loss           | 2.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 519          |
# | time/                   |              |
# |    fps                  | 1004         |
# |    iterations           | 45           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 7.680996e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | 0.0347       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 940          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 5.27e-05     |
# |    value_loss           | 1.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 531          |
# | time/                   |              |
# |    fps                  | 1004         |
# |    iterations           | 46           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 5.667971e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | 0.0183       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 957          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 6.98e-05     |
# |    value_loss           | 1.83e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 551           |
# | time/                   |               |
# |    fps                  | 1003          |
# |    iterations           | 47            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00037573712 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.511        |
# |    explained_variance   | 0.0252        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 808           |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000379     |
# |    value_loss           | 1.43e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | 552           |
# | time/                   |               |
# |    fps                  | 1003          |
# |    iterations           | 48            |
# |    time_elapsed         | 97            |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00013264074 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.518        |
# |    explained_variance   | 0.0247        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 739           |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -8.21e-05     |
# |    value_loss           | 1.65e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | 558          |
# | time/                   |              |
# |    fps                  | 1002         |
# |    iterations           | 49           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 5.879943e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.507       |
# |    explained_variance   | 0.0382       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 650          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000213    |
# |    value_loss           | 1.5e+03      |
# ------------------------------------------

# %% [markdown]
# ### Test Env

# %%
from gym_anytrading.envs import Actions

# %%
action_stats = {Actions.Sell: 0, Actions.Buy: 0}

# %%
forex_env = gym.make('forex-v0', df=data, frame_bound=(1100,2000), window_size=100)
forex_env.observation_space
# Out:
# Box(-10000000000.0, 10000000000.0, (100, 2), float32)

# %%
state, info = forex_env.reset(seed=2023)

while True:
    action, _states = model.predict(state)
    
    action_stats[Actions(action)] += 1
    state, reward, terminated, truncated, info = forex_env.step(action)
    done = terminated or truncated

    if done:
        break

forex_env.close()

print("action_stats:", action_stats)
print("info:", info)
# Out:
# action_stats: {<Actions.Sell: 0>: 718, <Actions.Buy: 1>: 181}
# info: {'total_reward': 35.60185432434082, 'total_profit': 0.9509048780251369, 'position': <Positions.Short: 0>}

# %%
plt.figure(figsize=(16, 6))
forex_env.unwrapped.render_all()
plt.show()
